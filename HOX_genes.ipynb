# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import scanpy as sc
import scanpy.external as sce
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets
import math
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
sc.settings.verbosity = 0  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.set_figure_params(scanpy=True, dpi=100, dpi_save=500, frameon=False, vector_friendly=True, fontsize=14, figsize=None, color_map=None, format='pdf', facecolor=None, transparent=True)

# %% [markdown]
# ## Load

# %%
segmentoid = sc.read('data/segmentoid_processed.h5ad')

# %%
somitoid = sc.read('data/somitoid_processed.h5ad')

# %% [markdown]
# ## Scraping

# %%
HOXA = [i for i in segmentoid.var_names if i.startswith('HOXA')]
HOXA = [x for x in HOXA if "AS" not in x]

HOXB = [i for i in segmentoid.var_names if i.startswith('HOXB')]
HOXB = [x for x in HOXB if "AS" not in x]

HOXC = [i for i in segmentoid.var_names if i.startswith('HOXC')]
HOXC = [x for x in HOXC if "AS" not in x]

HOXD = [i for i in segmentoid.var_names if i.startswith('HOXD')]
HOXD = [x for x in HOXD if "AS" not in x]

# %% [markdown]
# ## Sort

# %%
HOXA = ['HOXA1',
 'HOXA2',
 'HOXA3',
 'HOXA4',
 'HOXA5',
 'HOXA6',
 'HOXA7',
 'HOXA9',
 'HOXA10',
 'HOXA11',
 'HOXA13']

# %%
HOXB = ['HOXB1',
 'HOXB2',
 'HOXB3',
 'HOXB4',
 'HOXB5',
 'HOXB6',
 'HOXB7',
 'HOXB8',
 'HOXB9',
 'HOXB13']

# %%
HOXC = ['HOXC4',
 'HOXC5',
 'HOXC6',
 'HOXC8',
 'HOXC9',
 'HOXC10',
 'HOXC11',
 'HOXC12',
 'HOXC13']

# %%
HOXD = ['HOXD1',
 'HOXD3',
 'HOXD4',
 'HOXD8',
 'HOXD9',
 'HOXD10',
 'HOXD11',
 'HOXD12',
 'HOXD13']

# %% [markdown]
# ## Segmentoid timepoints

# %%
sc.pl.dotplot(segmentoid, HOXA, 'timepoint', return_fig=False, cmap='viridis',dot_max=0.5, standard_scale='var', categories_order=['iPSC', '24h', '48h', '72h', '98h'], title='Segmentoid - HOXA GENES - Timepoint', swap_axes=True, save='segmentoid_timepoint_dotplot_HOXA.pdf')

# %%
sc.pl.dotplot(segmentoid, HOXB, 'timepoint', return_fig=False, cmap='viridis',dot_max=0.5, standard_scale='var', categories_order=['iPSC', '24h', '48h', '72h', '98h'], title='Segmentoid - HOXB GENES - Timepoint', swap_axes=True, save='segmentoid_timepoint_dotplot_HOXB.pdf')

# %%
sc.pl.dotplot(segmentoid, HOXC, 'timepoint', return_fig=False, cmap='viridis',dot_max=0.5, standard_scale='var', categories_order=['iPSC', '24h', '48h', '72h', '98h'], title='Segmentoid - HOXC GENES - Timepoint', swap_axes=True, save='segmentoid_timepoint_dotplot_HOXC.pdf')

# %%
sc.pl.dotplot(segmentoid, HOXD, 'timepoint', return_fig=False, cmap='viridis',dot_max=0.5, standard_scale='var', categories_order=['iPSC', '24h', '48h', '72h', '98h'], title='Segmentoid - HOXD GENES - Timepoint', swap_axes=True, save='segmentoid_timepoint_dotplot_HOXD.pdf')

# %% [markdown]
# ## Somitoid timepoints

# %%
sc.pl.dotplot(somitoid, HOXA, 'timepoint', return_fig=False, cmap='viridis',dot_max=0.5, standard_scale='var', categories_order=['iPSC', '24h', '48h', '66h', '98h'], title='Somitoid - HOXA GENES - Timepoint', swap_axes=True, save='somitoid_timepoint_dotplot_HOXA.pdf')

# %%
sc.pl.dotplot(somitoid, HOXB, 'timepoint', return_fig=False, cmap='viridis',dot_max=0.5, standard_scale='var', categories_order=['iPSC', '24h', '48h', '66h', '98h'], title='Somitoid - HOXB GENES - Timepoint', swap_axes=True, save='somitoid_timepoint_dotplot_HOXB.pdf')

# %%
sc.pl.dotplot(somitoid, HOXC, 'timepoint', return_fig=False, cmap='viridis',dot_max=0.5, standard_scale='var', categories_order=['iPSC', '24h', '48h', '66h', '98h'], title='Somitoid - HOXC GENES - Timepoint', swap_axes=True, save='somitoid_timepoint_dotplot_HOXC.pdf')

# %%
sc.pl.dotplot(somitoid, HOXD, 'timepoint', return_fig=False, cmap='viridis',dot_max=0.5, standard_scale='var', categories_order=['iPSC', '24h', '48h', '66h', '98h'], title='Segmentoid - HOXD GENES - Timepoint', swap_axes=True, save='somitoid_timepoint_dotplot_HOXD.pdf')

# %% [markdown]
# ## Segmentoid clusters

# %%
sc.pl.dotplot(segmentoid, HOXA, 'leiden', return_fig=False, cmap='viridis',dot_max=0.5, standard_scale='var', categories_order=['iPSC', 'NMP',  'PSM Post', 'PSM Ant', 'Somite','Neural'], title='Segmentoid - HOXA GENES - Clusters', swap_axes=True, save='segmentoid_clusters_dotplot_HOXA.pdf')

# %%
sc.pl.dotplot(segmentoid, HOXB, 'leiden', return_fig=False, cmap='viridis',dot_max=0.5, standard_scale='var', categories_order=['iPSC', 'NMP',  'PSM Post', 'PSM Ant', 'Somite','Neural'], title='Segmentoid - HOXB GENES - Clusters', swap_axes=True, save='segmentoid_clusters_dotplot_HOXB.pdf')

# %%
sc.pl.dotplot(segmentoid, HOXC, 'leiden', return_fig=False, cmap='viridis',dot_max=0.5, standard_scale='var', categories_order=['iPSC', 'NMP',  'PSM Post', 'PSM Ant', 'Somite','Neural'], title='Segmentoid - HOXC GENES - Clusters', swap_axes=True, save='segmentoid_clusters_dotplot_HOXC.pdf')

# %%
sc.pl.dotplot(segmentoid, HOXD, 'leiden', return_fig=False, cmap='viridis',dot_max=0.5, standard_scale='var', categories_order=['iPSC', 'NMP',  'PSM Post', 'PSM Ant', 'Somite','Neural'], title='Segmentoid - HOXD GENES - Clusters', swap_axes=True, save='segmentoid_clusters_dotplot_HOXD.pdf')

# %% [markdown]
# ## Somitoid clusters

# %%
sc.pl.dotplot(somitoid, HOXA, 'leiden', return_fig=False, cmap='viridis',dot_max=0.5, standard_scale='var', categories_order=['iPSC', 'NMP',  'PSM Post', 'PSM Ant', 'Somite'], title='Segmentoid - HOXA GENES - Clusters', swap_axes=True, save='somitoid_clusters_dotplot_HOXA.pdf')

# %%
sc.pl.dotplot(somitoid, HOXB, 'leiden', return_fig=False, cmap='viridis',dot_max=0.5, standard_scale='var', categories_order=['iPSC', 'NMP',  'PSM Post', 'PSM Ant', 'Somite'], title='Segmentoid - HOXB GENES - Clusters', swap_axes=True, save='somitoid_clusters_dotplot_HOXB.pdf')

# %%
sc.pl.dotplot(somitoid, HOXC, 'leiden', return_fig=False, cmap='viridis',dot_max=0.5, standard_scale='var', categories_order=['iPSC', 'NMP',  'PSM Post', 'PSM Ant', 'Somite'], title='Segmentoid - HOXC GENES - Clusters', swap_axes=True, save='somitoid_clusters_dotplot_HOXC.pdf')

# %%
sc.pl.dotplot(somitoid, HOXD, 'leiden', return_fig=False, cmap='viridis',dot_max=0.5, standard_scale='var', categories_order=['iPSC', 'NMP',  'PSM Post', 'PSM Ant', 'Somite'], title='Segmentoid - HOXD GENES - Clusters', swap_axes=True, save='somitoid_clusters_dotplot_HOXD.pdf')
